# %% [markdown]
# Sentiment and Thematic Analysis

# %%
import sys
import os
import pandas as pd

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

from Scripts.sentiment_analysis import add_sentiment, aggregate_sentiment
from Scripts.theme_extraction import assign_themes

# %%
# 2. Load Cleaned Reviews
df = pd.read_csv("../data/processed/reviews_processed.csv") 
df.head()
# Out:
#                               review_id review_text  rating review_date  \
# 0  3463230e-f9f7-4be3-a632-fdd8d017ce84          🙏👍       5  2025-11-29
# 1  a6cbfa34-f2b1-4a16-96b6-c94f58cea76f   Very Good       5  2025-11-28
# 2  fc67d12c-92e2-45aa-a9e0-011f58a583bc        goof       5  2025-11-28
# 3  11306fb9-5571-4950-8d32-604c5402242f       good!       5  2025-11-28
# 4  809c46d2-730e-446a-9061-2a45e978ad9d    good jop       5  2025-11-27
#
#    review_year  review_month bank_code           bank_name  \
# 0         2025            11       BOA  Bank of Abyssinia
# 1         2025            11       BOA  Bank of Abyssinia
# 2         2025            11       BOA  Bank of Abyssinia
# 3         2025            11       BOA  Bank of Abyssinia
# 4         2025            11       BOA  Bank of Abyssinia
#
#              user_name  thumbs_up  text_length       source
# 0          Yasin Alemu          0            2  Google Play
# 1          Wariyo Dida          0            9  Google Play
# 2  Hailegebrail Tegegn          0            4  Google Play
# 3            Tsegay ab          0            5  Google Play
# 4       Yohanis Fikadu          0            8  Google Play

# %%
df.columns
# Out:
# Index(['review_id', 'review_text', 'rating', 'review_date', 'review_year',
#        'review_month', 'bank_code', 'bank_name', 'user_name', 'thumbs_up',
#        'text_length', 'source'],
#       dtype='object')

# %%
df = add_sentiment(df, text_col="review_text")
df[["review_text", "sentiment_label", "sentiment_score"]].head()
# Out:
#   review_text sentiment_label  sentiment_score
# 0          🙏👍        negative         0.697057
# 1   Very Good        positive         0.999852
# 2        goof        negative         0.997528
# 3       good!        positive         0.999827
# 4    good jop        positive         0.999841

# %%
agg = aggregate_sentiment(df)
agg.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 agg = aggregate_sentiment(df)
#       2 agg.head()
#
# File c:\Users\h\Desktop\WEEK 2\Web-Scraping\Scripts\sentiment_analysis.py:19, in aggregate_sentiment(df, by)
#      18 def aggregate_sentiment(df, by=["bank", "rating"]):
# ---> 19     return df.groupby(by)[["sentiment_score"]].mean().reset_index()
#
# File c:\Users\h\Desktop\WEEK 2\Web-Scraping\.venv\Lib\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# File c:\Users\h\Desktop\WEEK 2\Web-Scraping\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1331, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1328 self.dropna = dropna
#    1330 if grouper is None:
# -> 1331     grouper, exclusions, obj = get_grouper(
#    1332         obj,
#    1333         keys,
#    1334         axis=axis,
#    1335         level=level,
#    1336         sort=sort,
#    1337         observed=False if observed is lib.no_default else observed,
#    1338         dropna=self.dropna,
#    1339     )
#    1341 if observed is lib.no_default:
#    1342     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File c:\Users\h\Desktop\WEEK 2\Web-Scraping\.venv\Lib\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'bank'

# %%
themes = assign_themes(df)
themes
# Out:
# C:\Users\senta\AppData\Roaming\Python\Python312\site-packages\sklearn\feature_extraction\text.py:408: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ll', 've'] not in stop_words.
#   warnings.warn(
# {'Other': ['app',
#   'good',
#   'work',
#   'bank',
#   'use',
#   'update',
#   'banking',
#   'good app',
#   'easy',
#   'time',
#   'application',
#   'fast',
#   'dashen',
#   'bad',
#   'mobile',
#   'fix',
#   'need'],
#  'Transaction Performance': ['transaction', 'transfer'],
#  'User Interface & Experience': ['crash']}

# %%
df.to_csv("../data/reviews_with_sentiment.csv", index=False)
agg.to_csv("../data/sentiment_aggregate.csv", index=False)
